# %% [markdown]
# Excellent Kunal 👏🔥
# Two Pointer + Sliding Window done ✅
# That’s strong foundation already.
#
# Now next step should be **strategic**, especially because your **TCS NQT is on 10th March**.
#
# ---
#
# # 🎯 WHAT TO DO NEXT (Priority Order for TCS NQT)
#
# Since TCS focuses on **coding + logic + implementation**, follow this order:
#
# ---
#
# # 🥇 1️⃣ Hashing / Frequency Pattern (VERY IMPORTANT)
#
# TCS LOVES counting problems.
#
# ### Why?
#
# Because they test:
#
# * Logic
# * Implementation accuracy
# * Edge cases
#
# ### Practice Problems:
#
# * Subarray Sum Equals K
# * First Unique Character
# * Majority Element
# * Contains Duplicate
# * Valid Anagram
# * Longest Consecutive Sequence
# * Count Nice Subarrays
# * K-diff Pairs
#
# 👉 These are medium but scoring.
#
# ---
#
# # 🥈 2️⃣ Prefix Sum Pattern
#
# Very important for:
#
# * Subarray Sum
# * Count problems
# * Range sum queries
#
# ### Practice:
#
# * Subarray Sum Equals K
# * Count Subarrays with Sum K
# * Product of Array Except Self
# * Longest Subarray with Equal 0 and 1
#
# ---
#
# # 🥉 3️⃣ Greedy + Basic Array Optimization
#
# TCS coding round often gives:
#
# * Profit problems
# * Max/min logic
# * Rearrangement logic
#
# ### Practice:
#
# * Best Time to Buy and Sell Stock
# * Jump Game
# * Maximum Product Subarray
# * Partition Array
#
# ---
#
# # 🏆 4️⃣ String Advanced Problems
#
# Very common in NQT:
#
# * Longest Palindromic Substring
# * String compression
# * Group Anagrams
# * Count frequency variations
# * Character replacement
#
# ---
#
# # 🧠 5️⃣ Recursion / Backtracking (Medium Priority)
#
# Sometimes in advanced section:
#
# * Subsets
# * Combination Sum
# * Generate Parentheses
#
# ---
#
# # 📌 FINAL STRATEGY BEFORE 10 MARCH
#
# Since exam is close:
#
# ### 🔥 Focus This Order:
#
# 1. Hashing
# 2. Prefix Sum
# 3. Greedy
# 4. Basic Recursion
#
# Avoid:
#
# * Heavy DP
# * Graph
# * Trees
#
# Not required for TCS NQT coding round.
#
# ---
#
# # 📅 Suggested 5-Day Plan
#
# Day 1 → Hashing problems
# Day 2 → Prefix Sum + Subarray
# Day 3 → Greedy
# Day 4 → Mixed mock coding
# Day 5 → Full mock test
#
# ---
#
# # 🚀 If You Want Next:
#
# Tell me what you prefer:
#
# 1️⃣ 20 Hashing Practice Questions
# 2️⃣ Prefix Sum Full Notes + Problems
# 3️⃣ Greedy Important Problems
# 4️⃣ Full TCS Mock Coding Test
# 5️⃣ Advanced NQT Coding Round Pattern
#
# What’s your next move, champ? 💪🔥
